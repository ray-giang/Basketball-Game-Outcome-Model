# %%
import finviz

# %%
# tech stocks

# %%
test = finviz.get_news('AMZN')

# %%
test
# Out:
# [('Stock market investors are oblivious to the potential calamity of negative interest rates',
#   'https://www.marketwatch.com/story/stock-market-investors-are-oblivious-to-the-potential-calamity-of-negative-interest-rates-2020-05-08?siteid=yhoof2'),
#  ('Three dividend stocks of cash-flow-rich companies poised to thrive during this economic crisis',
#   'https://www.marketwatch.com/story/three-dividend-stocks-of-cash-flow-rich-companies-poised-to-thrive-during-this-economic-crisis-2020-05-07?siteid=yhoof2'),
#  ('Investing in These Stocks Now Could Make You a Millionaire Retiree',
#   'https://www.fool.com/investing/2020/05/09/investing-in-these-stocks-now-could-make-you-a-mil.aspx?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ('The coronavirus lockdowns are boosting Netflix, but leaving Hulu lagging behind',
# ...

# %%
url = "https://finviz.com/quote.ashx?t=aapl"

html = urlopen(url)
soup = BeautifulSoup(html)
